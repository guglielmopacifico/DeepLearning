# %%
from Class_Cos_1D import *
import matplotlib.pyplot as plt

# %% [markdown]
# # Figure 1

# %% [markdown]
# ### Plot a

# %%
domain_extrema = [-2*torch.pi, 2*torch.pi]

w = 1
n_hidden_layers = 2
neurons = 16
activation_function = nn.Tanh()

# Create the model
model = Cos_1D(domain_extrema, w, n_hidden_layers, neurons, activation_function)

num_points = 200
n_epochs = 10000

optimizer_ADAM = optim.Adam(model.parameters(),
                            lr=float(0.001))

history = model.fit(num_points, optimizer_ADAM, n_epochs, verbose=False)
# Out:
# Final loss:  1.665791387495119e-05 	 Training_time:  0  min  5  s

# %%
# MAKE THE PLOT
model.eval()

# test points
x = torch.linspace(-2*torch.pi, 2*torch.pi, 1000, dtype=torch.float32, device=DEVICE, requires_grad=True).reshape(-1, 1)   # the input has to be of shape (n, 1)

# Evaluate the exact solution
u_exact = model.exact_solution(x)

# Evaluate the approximate solution
u_approx = torch.tanh(model.w * model.normalize_input(x)) * model.unnormalize_output( model( model.normalize_input(x)) )

# Resale the approximate solution to the same scale as the exact solution
u_approx = model.restore_output(u_approx)

#Plot
# fig = plt.figure(figsize=(10, 5))
fig = plt.figure(figsize=(6, 4))
plt.plot(x.cpu().detach().numpy(), u_exact.cpu().detach().numpy(), label='Exact Solution')
plt.plot(x.cpu().detach().numpy(), u_approx.cpu().detach().numpy(), label='PINN')
plt.ylabel(r'$u$')
plt.xlabel(r'$x$')
plt.title(f'(a) PINN (w={model.w}, {model.n_hidden_layers} layers, {model.neurons[0]} hidden units)')
plt.legend()
plt.tight_layout()
plt.savefig("pinn_fig1_1.pdf")

# %% [markdown]
# ### Plot b

# %%
domain_extrema = [-2*torch.pi, 2*torch.pi]

w = 15
n_hidden_layers = 2
neurons = 16
activation_function = nn.Tanh()

# Create the model
model = Cos_1D(domain_extrema, w, n_hidden_layers, neurons, activation_function)

num_points = 200*15
n_epochs = 10000

optimizer_ADAM = optim.Adam(model.parameters(),
                            lr=float(0.001))

history = model.fit(num_points, optimizer_ADAM, n_epochs, verbose=False)
# Out:
# Final loss:  0.3440687954425812 	 Training_time:  0  min  13  s

# %%
# MAKE THE PLOT
model.eval()

# test points
x = torch.linspace(-2*torch.pi, 2*torch.pi, 1000, dtype=torch.float32, device=DEVICE, requires_grad=True).reshape(-1, 1)   # the input has to be of shape (n, 1)

# Evaluate the exact solution
u_exact = model.exact_solution(x)

# Evaluate the approximate solution
u_approx = torch.tanh(model.w * model.normalize_input(x)) * model.unnormalize_output( model( model.normalize_input(x)) )

# Resale the approximate solution to the same scale as the exact solution
u_approx = model.restore_output(u_approx)

#Plot
fig = plt.figure(figsize=(6, 4))
plt.plot(x.cpu().detach().numpy(), u_exact.cpu().detach().numpy(), label='Exact Solution')
plt.plot(x.cpu().detach().numpy(), u_approx.cpu().detach().numpy(), label='PINN')
plt.ylabel(r'$u$')
plt.xlabel(r'$x$')
plt.title(f'(b) PINN (w={model.w}, {model.n_hidden_layers} layers, {model.neurons[0]} hidden units)')
plt.legend()
plt.tight_layout()
plt.savefig("pinn_fig1_15.pdf")

# %% [markdown]
# ### Plot c

# %%
domain_extrema = [-2*torch.pi, 2*torch.pi]

w = 15
n_hidden_layers = 4
neurons = 64
activation_function = nn.Tanh()

# Create the model
model = Cos_1D(domain_extrema, w, n_hidden_layers, neurons, activation_function)

num_points = 200*15
n_epochs = 10000

optimizer_ADAM = optim.Adam(model.parameters(),
                            lr=float(0.001))

history = model.fit(num_points, optimizer_ADAM, n_epochs, verbose=False)
# Out:
# Final loss:  0.07984354346990585 	 Training_time:  0  min  58  s

# %%
# MAKE THE PLOT
model.eval()

# test points
x = torch.linspace(-2*torch.pi, 2*torch.pi, 1000, dtype=torch.float32, device=DEVICE, requires_grad=True).reshape(-1, 1)   # the input has to be of shape (n, 1)

# Evaluate the exact solution
u_exact = model.exact_solution(x)

# Evaluate the approximate solution
u_approx = torch.tanh(model.w * model.normalize_input(x)) * model.unnormalize_output( model( model.normalize_input(x)) )

# Resale the approximate solution to the same scale as the exact solution
u_approx = model.restore_output(u_approx)

#Plot
fig = plt.figure(figsize=(6, 4))
plt.plot(x.cpu().detach().numpy(), u_exact.cpu().detach().numpy(), label='Exact Solution')
plt.plot(x.cpu().detach().numpy(), u_approx.cpu().detach().numpy(), label='PINN')
plt.ylabel(r'$u$')
plt.xlabel(r'$x$')
plt.title(f'(c) PINN (w={model.w}, {model.n_hidden_layers} layers, {model.neurons[0]} hidden units)')
plt.legend()
plt.tight_layout()
plt.savefig("pinn_fig1_15_64.pdf")

# %% [markdown]
# ### Plot d

# %%
domain_extrema = [-2*torch.pi, 2*torch.pi]

w = 15
n_hidden_layers = 5
neurons = 128
activation_function = nn.Tanh()

# Create the model
model = Cos_1D(domain_extrema, w, n_hidden_layers, neurons, activation_function)

num_points = 200*15
n_epochs = 10000

optimizer_ADAM = optim.Adam(model.parameters(),
                            lr=float(0.001))

history = model.fit(num_points, optimizer_ADAM, n_epochs, verbose=False)
# Out:
# Final loss:  0.03667242079973221 	 Training_time:  2  min  20  s

# %%
# MAKE THE PLOT
model.eval()

# test points
x = torch.linspace(-2*torch.pi, 2*torch.pi, 1000, dtype=torch.float32, device=DEVICE, requires_grad=True).reshape(-1, 1)   # the input has to be of shape (n, 1)

# Evaluate the exact solution
u_exact = model.exact_solution(x)

# Evaluate the approximate solution
u_approx = torch.tanh(model.w * model.normalize_input(x)) * model.unnormalize_output( model( model.normalize_input(x)) )

# Resale the approximate solution to the same scale as the exact solution
u_approx = model.restore_output(u_approx)

#Plot
fig = plt.figure(figsize=(6, 4))
plt.plot(x.cpu().detach().numpy(), u_exact.cpu().detach().numpy(), label='Exact Solution')
plt.plot(x.cpu().detach().numpy(), u_approx.cpu().detach().numpy(), label='PINN')
plt.ylabel(r'$u$')
plt.xlabel(r'$x$')
plt.title(f'(d) PINN (w={model.w}, {model.n_hidden_layers} layers, {model.neurons[0]} hidden units)')
plt.legend()
plt.tight_layout()
plt.savefig("pinn_fig1_15_128.pdf")

# %% [markdown]
# ### Plot e
