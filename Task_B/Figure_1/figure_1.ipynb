# %%
from Class_Cos_1D import *
import matplotlib.pyplot as plt
# Out:
# Running on  cpu

# %% [markdown]
# # Figure 1

# %% [markdown]
# ### Plot a

# %%
domain_extrema = [-2*torch.pi, 2*torch.pi]

w = 1
n_hidden_layers = 2
neurons = 16
activation_function = nn.Tanh()

# Create the model
model = Cos_1D(domain_extrema, w, n_hidden_layers, neurons, activation_function)

num_points = 200
n_epochs = 10000

optimizer_ADAM = optim.Adam(model.parameters(),
                            lr=float(0.001))

history = model.fit(num_points, optimizer_ADAM, n_epochs, verbose=False)
# Out:
# Final loss:  1.5943895050440915e-05 	 Training_time:  0  min  5  s

# %%
# MAKE THE PLOT
model.eval()

# test points
x = torch.linspace(-2*torch.pi, 2*torch.pi, 1000, dtype=torch.float32, device=DEVICE, requires_grad=True).reshape(-1, 1)   # the input has to be of shape (n, 1)

# Evaluate the exact solution
u_exact = model.exact_solution(x)

# Evaluate the approximate solution
u_approx = torch.tanh(model.w * model.normalize_input(x)) * model.unnormalize_output( model( model.normalize_input(x)) )

# Resale the approximate solution to the same scale as the exact solution
u_approx = model.restore_output(u_approx)

#Plot
fig = plt.figure(figsize=(10, 5))
plt.plot(x.cpu().detach().numpy(), u_exact.cpu().detach().numpy(), label='Exact Solution')
plt.plot(x.cpu().detach().numpy(), u_approx.cpu().detach().numpy(), label='PINN')
plt.title(f'PINN (w={model.w}, {model.n_hidden_layers} layers, {model.neurons[0]} hidden units)')
plt.legend()

# %% [markdown]
# ### Plot b

# %%
domain_extrema = [-2*torch.pi, 2*torch.pi]

w = 15
n_hidden_layers = 2
neurons = 16
activation_function = nn.Tanh()

# Create the model
model = Cos_1D(domain_extrema, w, n_hidden_layers, neurons, activation_function)

num_points = 200*15
n_epochs = 10000

optimizer_ADAM = optim.Adam(model.parameters(),
                            lr=float(0.001))

history = model.fit(num_points, optimizer_ADAM, n_epochs, verbose=False)
# Out:
# Final loss:  0.37533581256866455 	 Training_time:  0  min  13  s

# %%
# MAKE THE PLOT
model.eval()

# test points
x = torch.linspace(-2*torch.pi, 2*torch.pi, 1000, dtype=torch.float32, device=DEVICE, requires_grad=True).reshape(-1, 1)   # the input has to be of shape (n, 1)

# Evaluate the exact solution
u_exact = model.exact_solution(x)

# Evaluate the approximate solution
u_approx = torch.tanh(model.w * model.normalize_input(x)) * model.unnormalize_output( model( model.normalize_input(x)) )

# Resale the approximate solution to the same scale as the exact solution
u_approx = model.restore_output(u_approx)

#Plot
fig = plt.figure(figsize=(10, 5))
plt.plot(x.cpu().detach().numpy(), u_exact.cpu().detach().numpy(), label='Exact Solution')
plt.plot(x.cpu().detach().numpy(), u_approx.cpu().detach().numpy(), label='PINN')
plt.title(f'PINN (w={model.w}, {model.n_hidden_layers} layers, {model.neurons[0]} hidden units)')
plt.legend()

# %% [markdown]
# ### Plot c

# %%
domain_extrema = [-2*torch.pi, 2*torch.pi]

w = 15
n_hidden_layers = 4
neurons = 64
activation_function = nn.Tanh()

# Create the model
model = Cos_1D(domain_extrema, w, n_hidden_layers, neurons, activation_function)

num_points = 200*15
n_epochs = 10000

optimizer_ADAM = optim.Adam(model.parameters(),
                            lr=float(0.001))

history = model.fit(num_points, optimizer_ADAM, n_epochs, verbose=False)
# Out:
# Final loss:  0.14306342601776123 	 Training_time:  0  min  53  s

# %%
# MAKE THE PLOT
model.eval()

# test points
x = torch.linspace(-2*torch.pi, 2*torch.pi, 1000, dtype=torch.float32, device=DEVICE, requires_grad=True).reshape(-1, 1)   # the input has to be of shape (n, 1)

# Evaluate the exact solution
u_exact = model.exact_solution(x)

# Evaluate the approximate solution
u_approx = torch.tanh(model.w * model.normalize_input(x)) * model.unnormalize_output( model( model.normalize_input(x)) )

# Resale the approximate solution to the same scale as the exact solution
u_approx = model.restore_output(u_approx)

#Plot
fig = plt.figure(figsize=(10, 5))
plt.plot(x.cpu().detach().numpy(), u_exact.cpu().detach().numpy(), label='Exact Solution')
plt.plot(x.cpu().detach().numpy(), u_approx.cpu().detach().numpy(), label='PINN')
plt.title(f'PINN (w={model.w}, {model.n_hidden_layers} layers, {model.neurons[0]} hidden units)')
plt.legend()

# %% [markdown]
# ### Plot d

# %%
domain_extrema = [-2*torch.pi, 2*torch.pi]

w = 15
n_hidden_layers = 5
neurons = 128
activation_function = nn.Tanh()

# Create the model
model = Cos_1D(domain_extrema, w, n_hidden_layers, neurons, activation_function)

num_points = 200*15
n_epochs = 10000

optimizer_ADAM = optim.Adam(model.parameters(),
                            lr=float(0.001))

history = model.fit(num_points, optimizer_ADAM, n_epochs, verbose=False)
# Out:
# Final loss:  0.05290067568421364 	 Training_time:  2  min  7  s

# %%
# MAKE THE PLOT
model.eval()

# test points
x = torch.linspace(-2*torch.pi, 2*torch.pi, 1000, dtype=torch.float32, device=DEVICE, requires_grad=True).reshape(-1, 1)   # the input has to be of shape (n, 1)

# Evaluate the exact solution
u_exact = model.exact_solution(x)

# Evaluate the approximate solution
u_approx = torch.tanh(model.w * model.normalize_input(x)) * model.unnormalize_output( model( model.normalize_input(x)) )

# Resale the approximate solution to the same scale as the exact solution
u_approx = model.restore_output(u_approx)

#Plot
fig = plt.figure(figsize=(10, 5))
plt.plot(x.cpu().detach().numpy(), u_exact.cpu().detach().numpy(), label='Exact Solution')
plt.plot(x.cpu().detach().numpy(), u_approx.cpu().detach().numpy(), label='PINN')
plt.title(f'PINN (w={model.w}, {model.n_hidden_layers} layers, {model.neurons[0]} hidden units)')
plt.legend()

# %% [markdown]
# ### Plot e
